# %% [markdown]
# <a href="https://colab.research.google.com/github/vini1lol/Harvardx/blob/master/CaseStudy6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)

# %%
G.add_nodes_from([2,3])
G.add_nodes_from(["u","v"])

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 'u', 'v'))

# %%
G.add_edge(1,2)
G.add_edge('u','v')

# %%
G.add_edges_from([(1,3),(1,4),(1,5),(1,6)])

# %%
G.add_edge("u","w")

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 3), (1, 4), (1, 5), (1, 6), ('u', 'v'), ('u', 'w')])

# %%
G.remove_node(2)

# %%
G.remove_nodes_from([4,5])

# %%
G.nodes()
# Out:
# NodeView((1, 3, 'u', 'v', 6, 'w'))

# %%
G.remove_edge(1,3)

# %%
G.remove_edges_from([(1,2),('u','v')])

# %%
G.nodes()
# Out:
# NodeView((1, 3, 'u', 'v', 6, 'w'))

# %%
G.edges()
# Out:
# EdgeView([(1, 6), ('u', 'w')])

# %%
G = nx.karate_club_graph()

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G,with_labels=True,node_color='lightblue',edge_color='gray')

# %%
G.degree()
# Out:
# DegreeView({0: 16, 1: 9, 2: 10, 3: 6, 4: 3, 5: 4, 6: 4, 7: 4, 8: 5, 9: 2, 10: 3, 11: 1, 12: 2, 13: 5, 14: 2, 15: 2, 16: 2, 17: 2, 18: 2, 19: 3, 20: 2, 21: 2, 22: 2, 23: 5, 24: 3, 25: 3, 26: 2, 27: 4, 28: 3, 29: 4, 30: 4, 31: 6, 32: 12, 33: 17})

# %%
G.degree()[33]
# Out:
# 17

# %%
G.degree(33)
# Out:
# 17

# %%
G.number_of_nodes(),G.number_of_edges()
# Out:
# (34, 78)

# %%
G.degree(0) is G.degree()[0]
# Out:
# True

# %%
from scipy.stats import bernoulli

# %%
bernoulli.rvs(p=0.2)
# Out:
# 0

# %%
N = 20
p = 0.2
def er_graph(N,p):
  G = nx.Graph()
  G.add_nodes_from(range(N))
  for node1 in G.nodes():
    for node2 in G.nodes():
      if node1 < node2 and bernoulli.rvs(p=p):
        G.add_edge(node1,node2)
  return G
nx.draw(er_graph(N,p))

# %%
nx.draw(er_graph(50,0.08),node_size=40,node_color='gray')

# %%
def plot_degree_distribution(G):
  degree_sequence = [d for n, d in G.degree()]
  plt.hist(degree_sequence, histtype="step")
  plt.xlabel("Degree $k$")
  plt.ylabel("$P(k)$")
  plt.title("Degree Distribution")

# %%
G = er_graph(500,0.08)
plot_degree_distribution(G)

# %%
G1 = er_graph(500,0.08)
plot_degree_distribution(G1)
G2 = er_graph(500,0.08)
plot_degree_distribution(G2)
G3 = er_graph(500,0.08)
plot_degree_distribution(G3)

# %%
a = nx.erdos_renyi_graph(100, 0.03)
b = nx.erdos_renyi_graph(100, 0.30)
plot_degree_distribution(a)
plot_degree_distribution(b)

# %%
import numpy as np
A1 = np.loadtxt("/content/drive/My Drive/havardx/Using Python for Research/week4/adj_allVillageRelationships_vilno_1.csv", delimiter=",")
A2 = np.loadtxt("/content/drive/My Drive/havardx/Using Python for Research/week4/adj_allVillageRelationships_vilno_2.csv", delimiter=",")

# %%
G1 = nx.to_networkx_graph(A1)
G2 = nx.to_networkx_graph(A2)

# %%
def basic_net_stats(G):
  print("Number of nodes: %d" % G.number_of_nodes())
  print("Number of edges: %d" % G.number_of_edges())
  degree_sequence = [d for n, d in G.degree()]
  print("Average degree: %.2f" % np.mean(degree_sequence))

# %%
basic_net_stats(G1)
# Out:
# Number of nodes: 843
# Number of edges: 3405
# Average degree: 8.08

# %%
basic_net_stats(G2)
# Out:
# Number of nodes: 877
# Number of edges: 3063
# Average degree: 6.99

# %%
plot_degree_distribution(G1)
plot_degree_distribution(G2)
